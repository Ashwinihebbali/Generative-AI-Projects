# %%
# !pip -q install google-genai

# %%
from google import genai
from getpass import getpass

# Enter your Gemini API key safely
api_key = getpass("Enter your Gemini API Key: ")

# Create client
client = genai.Client(api_key=api_key)
# Out:
# Enter your Gemini API Key: ··········

# %%
print("SMART ACADEMIC COMMUNICATION ASSISTANT")
print("-" * 50)

communication_type = input("Enter communication type (Notice / Email / WhatsApp Message): ")
purpose = input("Enter the purpose: ")
audience = input("Enter the target audience: ")
key_points = input("Enter the important points (comma separated): ")
tone = input("Enter the tone (Formal / Professional / Friendly / Concise): ")
length = input("Enter the length (Short / Medium / Detailed): ")
# Out:
# SMART ACADEMIC COMMUNICATION ASSISTANT
# --------------------------------------------------
# Enter communication type (Notice / Email / WhatsApp Message): Email
# Enter the purpose: AIISH Project Discussion
# Enter the target audience: AIISH
# Enter the important points (comma separated): Appointment for Discussion, Problem Statement to solve
# Enter the tone (Formal / Professional / Friendly / Concise): Professional
# Enter the length (Short / Medium / Detailed): Detailed

# %%
prompt = f'''
You are an academic communication assistant.

Generate a {communication_type} for the following requirement.

Purpose:
{purpose}

Target Audience:
{audience}

Important Points:
{key_points}

Tone:
{tone}

Length:
{length}

Instructions:
1. The content must be clear and grammatically correct.
2. Keep it suitable for academic or official use.
3. Use proper formatting.
4. Do not add unnecessary information.
5. Make the message natural and professional.
'''

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=prompt
)

print("\nGENERATED OUTPUT")
print("-" * 50)
print(response.text)
# Out:
# GENERATED OUTPUT
# --------------------------------------------------
# Subject: Request for Meeting: AIISH Project Discussion and Problem Statement Formulation
#
# Dear Esteemed Members of AIISH,
#
# I hope this email finds you well.
#
# I am writing to formally request a meeting to explore a potential collaborative project with the All India Institute of Speech and Hearing (AIISH). Our team/my research group [Choose one: 'Our team' if representing an organization/department, 'my research group' if individual PI, or 'I' if an individual academic] has been deeply impressed by AIISH's pioneering work and significant contributions in the fields of speech, hearing, and communication disorders. We are particularly interested in exploring opportunities where our expertise in [briefly mention your area of expertise, e.g., 'digital health technologies', 'linguistic data analysis', 'rehabilitation science research', 'AI-driven diagnostics'] could align with your ongoing initiatives and address critical challenges.
#
# Specifically, we are keen to engage in a discussion to jointly identify and define a pressing problem statement that, if successfully addressed through a collaborative project, could yield significant benefits for the community served by AIISH and advance the field. We believe that by synergizing our respective strengths, we can formulate an innovative and impactful solution to a pertinent challenge within speech and hearing sciences, clinical practice, rehabilitation, or related areas. Our goal is to work collaboratively with your experts to ensure the project is highly relevant, feasible, and aligned with AIISH's strategic objectives.
#
# To facilitate this initial discussion, I would be grateful if you could grant us an appointment at your earliest convenience. We are flexible regarding the timing and would be pleased to adapt to your schedule. A meeting lasting approximately 45-60 minutes would be ideal for this preliminary exploration, allowing us to present our preliminary thoughts and, more importantly, listen to your insights and perspectives on potential areas of focus and critical needs. We are available for a meeting either virtually or, if preferred and feasible, in person at your esteemed institution.
#
# Ahead of the meeting, we would be happy to provide any further information about our work or a brief concept note to help frame the discussion. Please let us know what would be most helpful.
#
# Thank you for considering our request. We highly value the opportunity to collaborate with AIISH and look forward to the possibility of contributing to your noble mission.
#
# Sincerely,
#
# [Your Name]
# [Your Title]
# [Your Department/Organization]
# [Your Email Address]
# [Your Phone Number]
# [Your Website (Optional)]
